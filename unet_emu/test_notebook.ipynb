# %%
import numpy as np

# %%
x = np.linspace(-3, 3, 128)
y = np.linspace(-3, 3, 128)
xx, yy = np.meshgrid(x, y)
r = np.sqrt(xx**2+yy**2)
vaz_ict = np.float32(r**(-0.5)*((r<3) & (r>0.4)))

# %%
import matplotlib.pyplot as plt
plt.imshow(vaz_ict)

# %%
vaz_ict = np.expand_dims(np.repeat(np.expand_dims(vaz_ict, 0), 10,axis=0), -1)

# %%
vr_ict = np.zeros(vaz_ict.shape)

# %%
np.concatenate([vaz_ict, vr_ict], axis=-1).shape
# Out:
# (10, 128, 128, 2)
