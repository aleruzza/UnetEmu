# %%
import numpy as np
import emcee
import astropy.units as u
import pandas as pd

# %% [markdown]
# # Test fit of model generate dwith simulation 4 in the test set

# %%
backendfilename = 'backend_fitid11_wrms_allp_tune_corr_new_fixedslopeflaringcorr_log3_changea.h5'
name = backendfilename.split('.')[0]
n_walkers=70
id=11

# %%
val_params = pd.read_csv('selected_val.csv', index_col=0)

# %%
__LABELS__ = ['Alpha', 'Aspect Ratio', 'PlanetMass', 'SigmaSlope', 'FlaringIndex', 'PlanetRadialPosition', 'PlanetAzimuthalPosition']
min_r = np.array([-4, 0.03, -5, 0.5, 0., 1,1])
max_r = np.array([-2, 0.1, -2, 1.2, 0.35, 1,1])
a = 2./(max_r-min_r)
b = -a*min_r -1
a[-2:] = [1,1]
b[-2:] = [0,0]

au_to_m = u.au.to('m')

log = [True, False, True, False, False, False, False]
def norm(data):
    new_data = data.copy()
    for i in range(data.shape[0]):
        if log[i]:
            new_data[i] = np.log10(data[i])
    return new_data*a+b

params_from_csv = val_params.loc[11, ['Alpha', 'AspectRatio', 'PlanetMass', 'SigmaSlope', 'FlaringIndex']]
target_params_nonorm = np.array([*params_from_csv, 400*au_to_m, np.pi/4])
target_params_norm = norm(target_params_nonorm)

par_ranges = [[1e-3, 1e-2], [0.03,0.1], [1e-4,1e-3], [0.5, 1.2], [0., 0.35], [300*au_to_m, 500*au_to_m], [-np.pi, np.pi]]
# Out:
# /tmp/ipykernel_52569/1522302106.py:4: RuntimeWarning: divide by zero encountered in divide
#   a = 2./(max_r-min_r)

# %%
target_params_norm
# Out:
# array([ 5.90000000e-01,  4.90000000e-01,  5.70000000e-01, -3.00000000e-02,
#        -3.00000000e-02,  5.98391483e+13,  7.85398163e-01])

# %%
reader = emcee.backends.HDFBackend(backendfilename)

tau = reader.get_autocorr_time()
burnin = int(2 * np.max(tau))
thin = int(0.5 * np.min(tau))
samples = reader.get_chain(flat=True)
log_prob_samples = reader.get_log_prob(discard=burnin, flat=True, thin=thin)
log_prior_samples = reader.get_blobs(discard=burnin, flat=True, thin=thin)

print("burn-in: {0}".format(burnin))
print("thin: {0}".format(thin))
print("flat chain shape: {0}".format(samples.shape))
print("flat log prob shape: {0}".format(log_prob_samples.shape))
print("flat log prior shape: {0}".format(log_prior_samples.shape))
# Out:
# /home/aleruzza/.local/lib/python3.10/site-packages/emcee/autocorr.py:38: RuntimeWarning: invalid value encountered in divide
#   acf /= acf[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_52569/314827774.py in <module>
#       2
#       3 tau = reader.get_autocorr_time()
# ----> 4 burnin = int(2 * np.max(tau))
#       5 thin = int(0.5 * np.min(tau))
#       6 samples = reader.get_chain(flat=True)
#
# ValueError: cannot convert float NaN to integer

# %%
chain = reader.get_chain()
chain = chain.reshape(-1,6)
chain2 = np.concatenate([chain, (2*chain[:,3]+0.5).reshape(-1,1)], axis=1)
chain = chain2[:, [0,1,2,6,3,4,5]]

# %%
target_params = target_params_norm

# %%
from corner import corner
import matplotlib.pyplot as plt
labels = ['$\\alpha$', '$h$', '$M_p/M_\\star$', '$\sigma$', '$\\beta$', '$R_p$', '$\phi_p$']
means = chain.reshape(-1,7).mean(axis=0)
stds = chain.reshape(-1,7).std(axis=0)
figure = corner(chain, labels=labels, fontsize=17)


# Extract the axes
axes = np.array(figure.axes).reshape((7,7))

# Loop over the diagonal
for i in range(7):
    ax = axes[i, i]
    ax.axvline(target_params[i], color="g")
    ax.set_xlim(par_ranges[i])
    ax.set_title(f'{labels[i]}:\n {means[i]:.2} $\pm$ {stds[i]:.2}', fontsize=17)

# Loop over the histograms
for yi in range(7):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(target_params[xi], color="g")
        ax.axhline(target_params[yi], color="g")
        ax.plot(target_params[xi], target_params[yi], "sg")
        
text = ''
for i, l in enumerate(labels):
    text = text + f'\t  {l}:  {target_params[i]:.2}\n'
axes[0,6].text(-0.5,-0.2,f'―■― Target values\n\n{text}', fontsize=20, color='g')
#plt.gcf().set_size_inches(7,7)
plt.savefig(f'{name}.png', dpi=500, bbox_inches='tight')
# Out:
# /home/aleruzza/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(chain.reshape(-1), bins=np.logspace(-4,-3, 50))
plt.xscale('log')

# %% [markdown]
# # Acceptance rate

# %%
chain = chain.reshape(-1,n_walkers,7)
print(f'Acceptance rate: {reader.accepted.sum()/(chain.shape[0]*chain.shape[1])*100:.2f} %')
# Out:
# Acceptance rate: 99.87 %

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(7, 1, figsize=(10,4*7), sharex=True)

for i in range(7):
    axs[i].plot(chain[:,::,i], color='black', alpha=0.1)
    axs[i].set_ylabel(labels[i])
    axs[i].axhline(target_params[i], color='g')
axs[-1].set_xlabel('# Step')
fig.tight_layout()
plt.savefig(f'{name}_chain.png', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Likelihood

# %%
plt.plot(-reader.get_log_prob()[:,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35428/2862328055.py in <module>
# ----> 1 plt.plot(-reader.get_log_prob()[:,:])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Effect of the convolution on noise

# %%
import numpy.random as rn
from scipy.ndimage import gaussian_filter
noise = rn.normal(size=(250,250))
blurred_noise = gaussian_filter(noise, 2)

# %%
plt.imshow(noise)

# %%
plt.imshow(blurred_noise)

# %%
plt.hist(noise.reshape(-1), bins=30)
plt.hist(blurred_noise.reshape(-1), bins=30)
# Out:
# (array([7.000e+00, 2.800e+01, 1.010e+02, 1.990e+02, 3.500e+02, 6.630e+02,
#         1.070e+03, 1.631e+03, 2.566e+03, 3.764e+03, 4.827e+03, 5.954e+03,
#         6.822e+03, 7.002e+03, 6.783e+03, 6.069e+03, 4.928e+03, 3.547e+03,
#         2.516e+03, 1.610e+03, 9.730e+02, 5.540e+02, 2.890e+02, 1.490e+02,
#         6.200e+01, 2.200e+01, 7.000e+00, 4.000e+00, 0.000e+00, 3.000e+00]),
#  array([-0.54886469, -0.50857232, -0.46827996, -0.4279876 , -0.38769524,
#         -0.34740288, -0.30711052, -0.26681816, -0.2265258 , -0.18623343,
#         -0.14594107, -0.10564871, -0.06535635, -0.02506399,  0.01522837,
#          0.05552073,  0.09581309,  0.13610545,  0.17639782,  0.21669018,
#          0.25698254,  0.2972749 ,  0.33756726,  0.37785962,  0.41815198,
#          0.45844434,  0.49873671,  0.53902907,  0.57932143,  0.61961379,
#          0.65990615]),
#  <BarContainer object of 30 artists>)

# %%
blurred_noise.reshape(-1).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35428/3674969898.py in <module>
# ----> 1 blurred_noise.reshape(-1).mean()
#
# NameError: name 'blurred_noise' is not defined

# %%
blurred_noise.reshape(-1).std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35428/394446937.py in <module>
# ----> 1 blurred_noise.reshape(-1).std()
#
# NameError: name 'blurred_noise' is not defined

# %%
1/np.sqrt(10)
# Out:
# 0.31622776601683794
