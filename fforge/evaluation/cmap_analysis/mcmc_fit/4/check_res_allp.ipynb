# %%
import numpy as np
import emcee
import astropy.units as u
import pandas as pd

# %% [markdown]
# # Test fit of model generate dwith simulation 4 in the test set

# %%
backendfilename = 'backend_fitid4_wrms_allp_tune_corr_new_fixedslopeflaringcorr_log.h5'
name = backendfilename.split('.')[0]
n_walkers=70
id=4

# %%
val_params = pd.read_csv('../selected_val.csv', index_col=0)

# %%
val_params.loc[id]
# Out:
# InvStokes1      588.843655
# Alpha             0.006166
# AspectRatio       0.085650
# FlaringIndex      0.302750
# PlanetMass        0.000610
# SigmaSlope        1.105500
# nx              600.000000
# rout              3.000000
# ny              193.000000
# maxder1500        0.855297
# Name: 4, dtype: float64

# %%
__LABELS__ = ['Alpha', 'Aspect Ratio', 'PlanetMass', 'SigmaSlope', 'FlaringIndex', 'PlanetRadialPosition', 'PlanetAzimuthalPosition']
min_r = np.array([-4, 0.03, -5, 0.5, 0., 1,1])
max_r = np.array([-2, 0.1, -2, 1.2, 0.35, 1,1])
a = 2./(max_r-min_r)
b = -a*min_r -1
a[-2:] = [1,1]
b[-2:] = [0,0]

au_to_m = u.au.to('m')

log = [True, False, True, False, False, False, False]
def norm(data):
    new_data = data.copy()
    for i in range(data.shape[0]):
        if log[i]:
            new_data[i] = np.log10(data[i])
    return new_data*a+b

params_from_csv = val_params.loc[id, ['Alpha', 'AspectRatio', 'PlanetMass', 'SigmaSlope', 'FlaringIndex']]
target_params_nonorm = np.array([*params_from_csv, 400*au_to_m, np.pi/4])
target_params_norm = norm(target_params_nonorm)

par_ranges = [[1e-3, 1e-2], [0.03,0.1], [1e-4,1e-3], [0.5, 1.2], [0., 0.35], [300*au_to_m, 500*au_to_m], [-np.pi, np.pi]]
# Out:
# /tmp/ipykernel_19179/1972104693.py:4: RuntimeWarning: divide by zero encountered in divide
#   a = 2./(max_r-min_r)

# %%
reader = emcee.backends.HDFBackend(backendfilename)

tau = reader.get_autocorr_time()
burnin = int(2 * np.max(tau))
thin = int(0.5 * np.min(tau))
samples = reader.get_chain(flat=True)
log_prob_samples = reader.get_log_prob(discard=burnin, flat=True, thin=thin)
log_prior_samples = reader.get_blobs(discard=burnin, flat=True, thin=thin)

print("burn-in: {0}".format(burnin))
print("thin: {0}".format(thin))
print("flat chain shape: {0}".format(samples.shape))
print("flat log prob shape: {0}".format(log_prob_samples.shape))
print("flat log prior shape: {0}".format(log_prior_samples.shape))
# Out:
# ---------------------------------------------------------------------------
# AutocorrError                             Traceback (most recent call last)
# /tmp/ipykernel_8964/314827774.py in <module>
#       1 reader = emcee.backends.HDFBackend(backendfilename)
#       2
# ----> 3 tau = reader.get_autocorr_time()
#       4 burnin = int(2 * np.max(tau))
#       5 thin = int(0.5 * np.min(tau))
#
# ~/.local/lib/python3.10/site-packages/emcee/backends/backend.py in get_autocorr_time(self, discard, thin, **kwargs)
#     148         """
#     149         x = self.get_chain(discard=discard, thin=thin)
# --> 150         return thin * autocorr.integrated_time(x, **kwargs)
#     151
#     152     @property
#
# ~/.local/lib/python3.10/site-packages/emcee/autocorr.py in integrated_time(x, c, tol, quiet)
#     110         msg += "N/{0} = {1:.0f};\ntau: {2}".format(tol, n_t / tol, tau_est)
#     111         if not quiet:
# --> 112             raise AutocorrError(tau_est, msg)
#     113         logger.warning(msg)
#     114
#
# AutocorrError: The chain is shorter than 50 times the integrated autocorrelation time for 5 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 63;
# tau: [257.93963502 202.50132199 128.38123092 176.12167022 112.43138587
#   57.30746413]

# %%
chain = reader.get_chain()
chain.shape
# Out:
# (3134, 70, 6)

# %%
chain = reader.get_chain()
chain = chain.reshape(-1,6)
chain2 = np.concatenate([chain, (chain[:,3]).reshape(-1,1)], axis=1)
chain = chain2[:, [0,1,2,6,3,4,5]]

# %%
target_params = target_params_norm

# %%
from corner import corner
import matplotlib.pyplot as plt
labels = ['$\\alpha$', '$h$', '$M_p/M_\\star$', '$\sigma$', '$\\beta$', '$R_p$', '$\phi_p$']
means = chain.reshape(-1,7).mean(axis=0)
stds = chain.reshape(-1,7).std(axis=0)
figure = corner(chain, labels=labels, fontsize=17)


# Extract the axes
axes = np.array(figure.axes).reshape((7,7))

# Loop over the diagonal
for i in range(7):
    ax = axes[i, i]
    ax.axvline(target_params[i], color="g")
    ax.set_xlim(par_ranges[i])
    ax.set_title(f'{labels[i]}:\n {means[i]:.2} $\pm$ {stds[i]:.2}', fontsize=17)

# Loop over the histograms
for yi in range(7):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(target_params[xi], color="g")
        ax.axhline(target_params[yi], color="g")
        ax.plot(target_params[xi], target_params[yi], "sg")
        
text = ''
for i, l in enumerate(labels):
    text = text + f'\t  {l}:  {target_params[i]:.2}\n'
axes[0,6].text(-0.5,-0.2,f'―■― Target values\n\n{text}', fontsize=20, color='g')
#plt.gcf().set_size_inches(7,7)
plt.savefig(f'{name}.png', dpi=500, bbox_inches='tight')
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(chain.reshape(-1), bins=np.logspace(-4,-3, 50))
plt.xscale('log')

# %% [markdown]
# # Acceptance rate

# %%
chain = chain.reshape(-1,n_walkers,7)
print(f'Acceptance rate: {reader.accepted.sum()/(chain.shape[0]*chain.shape[1])*100:.2f} %')
# Out:
# Acceptance rate: 2.26 %

# %%
chain[:, 1,0]
# Out:
# array([0.00695326, 0.00680785, 0.00680785, ..., 0.00999694, 0.00999694,
#        0.00999694])

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(7, 1, figsize=(10,4*7), sharex=True)

for i in range(7):
    axs[i].plot(chain[:,:,i], color='black', alpha=0.1)
    axs[i].set_ylabel(labels[i])
    axs[i].axhline(target_params_nonorm[i], color='g')
axs[-1].set_xlabel('# Step')
fig.tight_layout()
plt.savefig(f'{name}_chain.png', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Likelihood

# %%
plt.plot(-reader.get_log_prob()[:,:])
plt.yscale('log')
#plt.ylim(4.2e4,4.205e4)
#plt.xlim(125,2000)

# %%
likelihood = -reader.get_log_prob().reshape(-1)

# %%
chain_flat = chain.reshape(-1,7)

# %%
fig, axs = plt.subplots(3,3, figsize=(10,10), sharey=True)

for i, ax, in enumerate(axs.flatten()):
    
    if i < 7:
        ax.scatter(chain_flat[:,i], likelihood, marker='.', c=np.log10(np.arange(len(likelihood))))
        ax.set_yscale('log')
        #ax.set_ylim(4.195e4, 4.24e4)
        ax.set_xlabel(labels[i])
    else:
        ax.axis('off')
        
    if i%3==0:
        ax.set_ylabel('-log $L$')
        
plt.tight_layout()
plt.savefig(f'{name}_logL.png', bbox_inches='tight', dpi=500)
# Out:
# /tmp/ipykernel_8964/3894593342.py:6: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(chain_flat[:,i], likelihood, marker='.', c=np.log10(np.arange(len(likelihood))))
