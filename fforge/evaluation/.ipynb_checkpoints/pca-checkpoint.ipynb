# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import pandas as pd
import evaluation_lib as plot_gen
from tqdm import tqdm

testset_params = '../data/data/data/gas_tri_256/testpara.csv'
testparams = pd.read_csv(testset_params, index_col=0)
#load the data and parameters of the test set
testset_cmaps = np.load('cmaps_from_simulations_testset_parfile_R261_phi0.99_hd163296like3corr.npy')
testset = testset_cmaps[:, 42:64] #only the central channels are present in the testset map
emulations = h5py.File("cmaps_emulations_small.h5", "r", swmr=True)

# %%
emucmaps_mp = emulations['PlanetMass']

# %%
emucmaps_mp.shape
# Out:
# (233, 20, 22, 250, 250)

# %%
from sklearn.decomposition import PCA
from tqdm import tqdm
expl_ratio = []

for i in tqdm(range(20)):
    pca = PCA(n_components=22)
    pca.fit(emucmaps_mp[20,i].reshape(22, -1))
    expl_ratio.append(pca.explained_variance_ratio_)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:02<00:00,  8.46it/s]

# %%
expl_ratio = np.array(expl_ratio)

# %%
expl_ratio.shape
# Out:
# (20, 22)

# %%
plt.plot(expl_ratio)
# Out:
# [<matplotlib.lines.Line2D at 0x7f4a1ef155d0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef15720>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef15870>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef159c0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef15b10>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef15c60>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef15db0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef15f00>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef14760>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16080>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef161d0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16320>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16470>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef165c0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16710>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16860>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef169b0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16b00>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16c50>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16da0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef16ef0>,
#  <matplotlib.lines.Line2D at 0x7f4a1ef17040>]

# %%
plt.imshow(pca.components_[2].reshape(250,250))
