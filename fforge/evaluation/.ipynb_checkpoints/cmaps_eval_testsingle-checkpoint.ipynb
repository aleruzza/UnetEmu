# %%
from discminer.emulator import Emulator
import discminer.emulator as emulib
import torch
import numpy as np
#loading the datacube under exam
from discminer.core import Data
from sys import path as syspath
from astropy import units as u
import json
import matplotlib.pyplot as plt
from discminer.mining_utils import get_noise_mask, init_data_and_model
# Out:
# /home/aleruzza/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#load data
import pandas as pd
params_test = pd.read_csv('../data/data/gas_tri_256/testpara.csv')
emu_data_vr = np.load('../results/data/vr_256/1980.npy')
emu_data_vphi = np.load('../results/data/vaz_256/1800.npy')
testset_data = np.load('../data/data/gas_tri_256/datatest.npy')
xy = np.linspace(-3,3,256)
xx, yy = np.meshgrid(xy, xy)
rrr = np.sqrt(xx**2+yy**2)
mask = (rrr>0.4) & (rrr<3)

# %% [markdown]
# # Instantiate needed models

# %%
datacube, model = init_data_and_model(Rmin=0, Rmax=1, parfile='parfile.json', )
simid = 20
import discminer.units as ucf
emu_params = {
        'alpha': params_test.loc[simid, 'Alpha'],
        'h': params_test.loc[simid, 'AspectRatio'],
        'planetMass': params_test.loc[simid, 'PlanetMass'],
        'sigmaSlope': params_test.loc[simid, 'SigmaSlope'],
        'flaringIndex': params_test.loc[simid, 'FlaringIndex'],
        'R_p': 400*ucf.au,
        'phi_p': np.pi,
        'extrap_vfunc': model.keplerian
    }

import torch
def vr_norm(data):
    return data * 1e-2


xy = np.linspace(-3, 3, 256)
xx, yy = np.meshgrid(xy, xy)
rr = np.sqrt(xx**2 + yy**2)
rr = torch.tensor(rr, dtype=torch.float)

def vaz_norm(data):
    return data * 1e-2 + rr**-0.5


labels = ["vphi", "vr"]
pths = [
    "../../../SCIENCE/UnetEmu/outputs/vphi_256/model__epoch_1980_test_vaz_256.pth",
    "../../../SCIENCE/UnetEmu/outputs/vr_256/model__epoch_1980_test_vr_256.pth",
]
params = [
    "../../../SCIENCE/UnetEmu/outputs/vphi_256/params.py",
    "../../../SCIENCE/UnetEmu/outputs/vr_256/params.py",
]
norm_funcs = [vaz_norm, vr_norm]
emu = Emulator(
    model_pths=pths,
    labels=["vphi", "vr"],
    model_params=params,
    norm_funcs=norm_funcs,
    ict_gen=emulib.generate_ict_128x128_disc_tri_slopes,
)
# Out:
#      _  _                        _
#   __| |(_) ___   ___  _ __ ___  (_) _ __    ___  _ __
#  / _` || |/ __| / __|| '_ ` _ \ | || '_ \  / _ \| '__|
# | (_| || |\__ \| (__ | | | | | || || | | ||  __/| |
#  \__,_||_||___/ \___||_| |_| |_||_||_| |_| \___||_|
#
#
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 120689578165943.16
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 107118059336037.9
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# Setting beam_info var to Beam: BMAJ=0.165413767099392 arcsec BMIN=0.12207780778406399 arcsec BPA=6.09619140625 deg
# Setting beam_kernel var to <astropy.convolution.kernels.Gaussian2DKernel object at 0x7ff484162a40>
# Available categories for prototyping: dict_keys(['velocity', 'orientation', 'intensity', 'linewidth', 'lineslope', 'height_upper', 'height_lower'])
# Using default and/or tag-based parametric forms for model...
# Setting velocity function to <function keplerian_vertical at 0x7ff48bf1dab0>
# Setting upper surface height function to <function z_upper_exp_tapered at 0x7ff48bf1dbd0>
# Setting lower surface height function to <function z_lower_exp_tapered at 0x7ff48bf1dc60>
# Setting intensity function to <function intensity_powerlaw_rout at 0x7ff48bf1df30>
# Setting linewidth function to <function linewidth_powerlaw at 0x7ff48bf1e200>
# Setting lineslope function to <function lineslope_powerlaw at 0x7ff48bf1e290>
# Setting line profile function to <function line_profile_bell at 0x7ff48bf1e320>
# Setting composite upper+lower line profile function to <function line_uplow_mask at 0x7ff48bf1e440>

# %% [markdown]
# # Overview of the specific case that we test here

# %%
fig, axs = plt.subplots(3,2,figsize=(10,11))

im1 = axs[0, 0].pcolormesh(xx, yy, testset_data[simid, 1] - rrr**-0.5 * mask, vmin=-0.05, vmax=0.05, cmap='bwr')
im2 = axs[0, 1].pcolormesh(xx, yy, testset_data[simid, 2], vmin=-0.05, vmax=0.05, cmap='bwr')

im3 = axs[1, 0].pcolormesh(xx, yy, (emu_data_vphi[simid, 0])*1e-2 * mask, vmin=-0.05, vmax=0.05, cmap='bwr')
im4 = axs[1, 1].pcolormesh(xx, yy, emu_data_vr[simid, 0]*1e-2*mask, vmin=-0.05, vmax=0.05, cmap='bwr')

im5 = axs[2, 0].pcolormesh(xx, yy, ((emu_data_vphi[simid, 0])*1e-2 -(testset_data[simid, 1] - rrr**-0.5 )) * mask, vmin=-0.01, vmax=0.01, cmap='bwr')
im6 = axs[2, 1].pcolormesh(xx, yy, (emu_data_vr[simid, 0]*1e-2-testset_data[simid, 2])*mask, vmin=-0.01, vmax=0.01, cmap='bwr')

# Add colorbars
fig.colorbar(im1, ax=axs[0, 0])
fig.colorbar(im2, ax=axs[0, 1])
fig.colorbar(im3, ax=axs[1, 0])
fig.colorbar(im4, ax=axs[1, 1])
fig.colorbar(im5, ax=axs[2, 0])
fig.colorbar(im6, ax=axs[2, 1])

axs[0,0].set_title('v_phi simulation')
axs[0,1].set_title('v_r simulation')

axs[0,0].set_title('v_phi emulation')
axs[0,1].set_title('v_r emulation')

axs[0,0].set_title('v_phi emulation')
axs[0,1].set_title('v_r emulation')

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
coord = {}
coord['x'] = xx*emu_params['R_p']
coord['y'] = yy*emu_params['R_p']
res = emu.emulate_v2d(coord, **emu_params)

# %%
from astropy.constants import G

# %%
vscale = np.sqrt(G.si*u.M_sun/(emu_params['R_p']*u.m)).to('km/s')

# %%
vscale
# Out:
# <Quantity 1.48923459 km / s>

# %%
plt.pcolormesh(coord['x'], coord['y'], res[1]*mask/vscale, vmax=0.04, vmin=-0.04, cmap='bwr')
plt.colorbar()
plt.gcf().set_size_inches(6,5)

# %% [markdown]
# # Generate channel maps from emulator

# %%
from discminer import units as ucf
from tqdm import tqdm

model.velocity_func = emu.emulate_v2d
model.params['orientation']['incl'] = np.pi/4

modelcubes = []
for simid in tqdm([simid]):
    emu_params = {
        'alpha': params_test.loc[simid, 'Alpha'],
        'h': params_test.loc[simid, 'AspectRatio'],
        'planetMass': params_test.loc[simid, 'PlanetMass'],
        'sigmaSlope': params_test.loc[simid, 'SigmaSlope'],
        'flaringIndex': params_test.loc[simid, 'FlaringIndex'],
        'R_p': 400*ucf.au,
        'phi_p': np.pi/4,
        'extrap_vfunc': model.keplerian
    }
    model.params['velocity'].update(emu_params)
    modelcube = model.make_model(make_convolve=False)
    modelcube.convert_to_tb()
    modelcubes.append(modelcube.data)
# Out:
# Setting velocity function to <bound method Emulator.emulate_v2d of <discminer.emulator.Emulator object at 0x7ff591f73460>>
#   0%|          | 0/1 [00:00<?, ?it/s]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'alpha': 0.0053703179637025,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7ff48c3ef6d0>,
#               'flaringIndex': 0.09275,
#               'h': 0.07585,
#               'phi_p': 0.7853981633974483,
#               'planetMass': 0.0014962356560944,
#               'sigmaSlope': 0.6855,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
# 100%|██████████| 1/1 [00:21<00:00, 21.23s/it]

# %%
modelcubes_arr_emu = np.array(modelcubes)

# %%
plt.imshow(modelcubes_arr_emu[0,60])

# %%
modelcube.show(chan_init=60)

# %% [markdown]
# # Generate cmaps from simulations

# %%
from scipy.interpolate import griddata
from discminer import units as u
testset_data = np.load('../data/data/gas_tri_256/datatest.npy')
def hypot_func(x, y): return np.sqrt(xx**2+yy**2)
def per_b(t):
        shape = t.shape
        t = t.flatten()
        t[t > np.pi] = t[t > np.pi] - 2 * np.pi
        t[t < -np.pi] = t[t < -np.pi] + 2 * np.pi
        return t.reshape(*shape)
def simulations_v2d(
        coord,
        R_p,
        phi_p,
        simid,
        extrap_vfunc,
        **extrap_kwargs,
    ):

        G = 6.67384e-11
        if "Mstar" in extrap_kwargs.keys():
            Mstar = extrap_kwargs["Mstar"]
        else:
            Mstar = 1

        if "v_sign" in extrap_kwargs.keys():
            v_sign = extrap_kwargs["v_sign"]
        else:
            v_sign = 1

        v3d = testset_data[simid,[1,2]]
        v3d = v3d[:, :, ::-1]

        x = np.linspace(-3, 3, 256)
        y = np.linspace(-3, 3, 256)
        xx, yy = np.meshgrid(x, y)

        rr = hypot_func(xx, yy)
        pp = np.arctan2(yy, xx)
        rr_dom = rr[(rr > 0.5) & (rr < 2.9)] * R_p
        pp_dom = per_b(pp[(rr > 0.5) & (rr < 2.9)] + phi_p)
        v3d_dom = v3d[:, (rr > 0.5) & (rr < 2.9)]
        x_dom = rr_dom * np.cos(pp_dom)
        y_dom = rr_dom * np.sin(pp_dom)

        if "R" not in coord.keys():
            R = hypot_func(coord["x"], coord["y"])
        else:
            R = coord["R"]

        if "phi" not in coord.keys():
            phi = np.arctan2(coord["x"], coord["y"])
        else:
            phi = coord["phi"]

        vphi_interp = (
            (
                griddata(
                    (x_dom, y_dom), v3d_dom[0].reshape(-1), (coord["x"], coord["y"])
                )
                * np.sqrt(G * Mstar * u.MSun / R_p)
            )
            * 1e-3
            * (-1)
            * v_sign
        )
        vr_interp = (
            griddata((x_dom, y_dom), v3d_dom[1].reshape(-1), (coord["x"], coord["y"]))
            * 1e-3
        )

        mask = (R > 2.9 * R_p) | (R < 0.5 * R_p)
        vphi_interp[mask] = extrap_vfunc(coord, **extrap_kwargs)[mask]
        vr_interp[mask] = 0
        v3d_interp = np.concatenate(
            [
                np.expand_dims(vphi_interp, axis=0),
                np.expand_dims(vr_interp, axis=0),
                -np.zeros((1, *vphi_interp.shape)) * v_sign,
            ],
            axis=0,
        )

        return v3d_interp

# %%
from discminer import units as ucf
from tqdm import tqdm
datacube, model = init_data_and_model(Rmin=0, Rmax=1, parfile='parfile.json', )
emu_params = {
    'simid': 0,
    'R_p': 400*ucf.au,
    'phi_p':np.pi/4,
    'extrap_vfunc': model.keplerian
}
model.velocity_func = simulations_v2d
model.params['orientation']['incl'] = np.pi/4
model.params['velocity'].update(emu_params)
modelcubes_sim = []
for i in tqdm([simid]):
    model.params['velocity']['simid'] = i
    modelcube = model.make_model(make_convolve=False)
    modelcube.convert_to_tb()
    modelcubes_sim.append(np.expand_dims(modelcube.data, axis=0))
# Out:
#      _  _                        _
#   __| |(_) ___   ___  _ __ ___  (_) _ __    ___  _ __
#  / _` || |/ __| / __|| '_ ` _ \ | || '_ \  / _ \| '__|
# | (_| || |\__ \| (__ | | | | | || || | | ||  __/| |
#  \__,_||_||___/ \___||_| |_| |_||_||_| |_| \___||_|
#
#
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 120689578165943.16
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 107118059336037.9
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# Setting beam_info var to Beam: BMAJ=0.165413767099392 arcsec BMIN=0.12207780778406399 arcsec BPA=6.09619140625 deg
# Setting beam_kernel var to <astropy.convolution.kernels.Gaussian2DKernel object at 0x7ff47ae81ed0>
# Available categories for prototyping: dict_keys(['velocity', 'orientation', 'intensity', 'linewidth', 'lineslope', 'height_upper', 'height_lower'])
# Using default and/or tag-based parametric forms for model...
# Setting velocity function to <function keplerian_vertical at 0x7ff48bf1dab0>
# Setting upper surface height function to <function z_upper_exp_tapered at 0x7ff48bf1dbd0>
# Setting lower surface height function to <function z_lower_exp_tapered at 0x7ff48bf1dc60>
# Setting intensity function to <function intensity_powerlaw_rout at 0x7ff48bf1df30>
# Setting linewidth function to <function linewidth_powerlaw at 0x7ff48bf1e200>
# Setting lineslope function to <function lineslope_powerlaw at 0x7ff48bf1e290>
# Setting line profile function to <function line_profile_bell at 0x7ff48bf1e320>
# Setting composite upper+lower line profile function to <function line_uplow_mask at 0x7ff48bf1e440>
# Setting velocity function to <function simulations_v2d at 0x7ff47adfb2e0>
#   0%|          | 0/1 [00:00<?, ?it/s]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7ff48c3ef6d0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 2,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
# 100%|██████████| 1/1 [00:14<00:00, 14.87s/it]

# %%
modelcubes_arr_sim = np.concatenate(modelcubes, axis=0)

# %%
plt.imshow(modelcubes_arr_sim[60])

# %% [markdown]
# # comparison

# %%
modelcubes_arr_sim.shape
# Out:
# (133, 250, 250)

# %%
modelcubes_arr_emu = modelcubes_arr_emu[0]

# %%
mse = ((modelcubes_arr_emu-modelcubes_arr_sim))

# %%
res = modelcubes_arr[[1],48:84]-modelcubes_sim[:, 48:84]

# %%
np.max(np.abs(mse))
# Out:
# 0.0

# %%
fig, axs = plt.subplots(3,12,figsize=(24,6))
axs = axs.flatten()
for i in range(36):
    axs[i].imshow(mse[i], )
    axs[i].axis('off')

# %%
plt.scatter(range(1), (res**2).mean(axis=(1,2,3)))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /tmp/ipykernel_18149/1361019227.py in <module>
# ----> 1 plt.scatter(range(1), (res**2).mean(axis=(1,2,3)))
#
# ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     104     is_float16_result = False
#     105
# --> 106     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     107     if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     108         warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis, keepdims, where)
#      75         items = 1
#      76         for ax in axis:
# ---> 77             items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      78         items = nt.intp(items)
#      79     else:
#
# AxisError: axis 3 is out of bounds for array of dimension 3

# %% [markdown]
# # Generate cmaps from precomputed emulations

# %%
emu_data_vphi.shape
# Out:
# (233, 1, 256, 256)

# %%
from scipy.interpolate import griddata
from discminer import units as u
emu_data_vr = np.load('../results/data/vr_256/1980.npy')
emu_data_vphi = np.load('../results/data/vaz_256/1800.npy')
def hypot_func(x, y): return np.sqrt(xx**2+yy**2)
def per_b(t):
        shape = t.shape
        t = t.flatten()
        t[t > np.pi] = t[t > np.pi] - 2 * np.pi
        t[t < -np.pi] = t[t < -np.pi] + 2 * np.pi
        return t.reshape(*shape)
def simulations_v2d(
        coord,
        R_p,
        phi_p,
        simid,
        extrap_vfunc,
        **extrap_kwargs,
    ):

        G = 6.67384e-11
        if "Mstar" in extrap_kwargs.keys():
            Mstar = extrap_kwargs["Mstar"]
        else:
            Mstar = 1

        if "v_sign" in extrap_kwargs.keys():
            v_sign = extrap_kwargs["v_sign"]
        else:
            v_sign = 1

        v3d = np.concatenate([emu_data_vphi[simid], emu_data_vr[simid]], axis=0)
        v3d = v3d[:, :, ::-1]

        x = np.linspace(-3, 3, 256)
        y = np.linspace(-3, 3, 256)
        xx, yy = np.meshgrid(x, y)

        rr = hypot_func(xx, yy)
        pp = np.arctan2(yy, xx)
        rr_dom = rr[(rr > 0.5) & (rr < 2.9)] * R_p
        pp_dom = per_b(pp[(rr > 0.5) & (rr < 2.9)] + phi_p)
        v3d_dom = v3d[:, (rr > 0.5) & (rr < 2.9)]
        x_dom = rr_dom * np.cos(pp_dom)
        y_dom = rr_dom * np.sin(pp_dom)

        if "R" not in coord.keys():
            R = hypot_func(coord["x"], coord["y"])
        else:
            R = coord["R"]

        if "phi" not in coord.keys():
            phi = np.arctan2(coord["x"], coord["y"])
        else:
            phi = coord["phi"]

        vphi_interp = (
            (
                griddata(
                    (x_dom, y_dom), v3d_dom[0].reshape(-1), (coord["x"], coord["y"])
                )
                * np.sqrt(G * Mstar * u.MSun / R_p)
            )
            * 1e-3
            * (-1)
            * v_sign
        )
        vr_interp = (
            griddata((x_dom, y_dom), v3d_dom[1].reshape(-1), (coord["x"], coord["y"]))
            * 1e-3
        )

        mask = (R > 2.9 * R_p) | (R < 0.5 * R_p)
        vphi_interp[mask] = extrap_vfunc(coord, **extrap_kwargs)[mask]
        vr_interp[mask] = 0
        v3d_interp = np.concatenate(
            [
                np.expand_dims(vphi_interp, axis=0),
                np.expand_dims(vr_interp, axis=0),
                -np.zeros((1, *vphi_interp.shape)) * v_sign,
            ],
            axis=0,
        )

        return v3d_interp

# %%
datacube, model = init_data_and_model(Rmin=0, Rmax=1, parfile='parfile.json')
# Out:
#      _  _                        _
#   __| |(_) ___   ___  _ __ ___  (_) _ __    ___  _ __
#  / _` || |/ __| / __|| '_ ` _ \ | || '_ \  / _ \| '__|
# | (_| || |\__ \| (__ | | | | | || || | | ||  __/| |
#  \__,_||_||___/ \___||_| |_| |_||_||_| |_| \___||_|
#
#
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 120689578165943.16
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 107118059336037.9
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# Setting beam_info var to Beam: BMAJ=0.165413767099392 arcsec BMIN=0.12207780778406399 arcsec BPA=6.09619140625 deg
# Setting beam_kernel var to <astropy.convolution.kernels.Gaussian2DKernel object at 0x7f78256f73a0>
# Available categories for prototyping: dict_keys(['velocity', 'orientation', 'intensity', 'linewidth', 'lineslope', 'height_upper', 'height_lower'])
# Using default and/or tag-based parametric forms for model...
# Setting velocity function to <function keplerian_vertical at 0x7f7955de1ea0>
# Setting upper surface height function to <function z_upper_exp_tapered at 0x7f7955de1fc0>
# Setting lower surface height function to <function z_lower_exp_tapered at 0x7f7955de2050>
# Setting intensity function to <function intensity_powerlaw_rout at 0x7f7955de2320>
# Setting linewidth function to <function linewidth_powerlaw at 0x7f7955de25f0>
# Setting lineslope function to <function lineslope_powerlaw at 0x7f7955de2680>
# Setting line profile function to <function line_profile_bell at 0x7f7955de2710>
# Setting composite upper+lower line profile function to <function line_uplow_mask at 0x7f7955de2830>

# %%
from discminer import units as ucf
from tqdm import tqdm

emu_params = {
    'simid': 0,
    'R_p': 400*ucf.au,
    'phi_p':np.pi/4,
    'extrap_vfunc': model.keplerian
}
model.params['velocity'].update(emu_params)
model.velocity_func = simulations_v2d
model.params['orientation']['incl'] = np.pi/4

modelcubes = []
for simid in tqdm(range(0, 10)):
    model.params['velocity']['simid'] = simid
    modelcube = model.make_model(make_convolve=False)
    modelcube.convert_to_tb()
    modelcubes.append(np.expand_dims(modelcube.data, axis=0))
# Out:
# Setting velocity function to <function simulations_v2d at 0x7f7823e21a20>
#   0%|          | 0/10 [00:00<?, ?it/s]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 0,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  10%|█         | 1/10 [00:12<01:56, 12.93s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 1,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  20%|██        | 2/10 [00:28<01:53, 14.22s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 2,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  30%|███       | 3/10 [00:42<01:39, 14.18s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 3,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  40%|████      | 4/10 [00:56<01:25, 14.22s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 4,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  50%|█████     | 5/10 [01:11<01:12, 14.43s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 5,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  60%|██████    | 6/10 [01:27<01:00, 15.18s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 6,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  70%|███████   | 7/10 [01:41<00:43, 14.54s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 7,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  80%|████████  | 8/10 [01:53<00:28, 14.01s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 8,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
#  90%|█████████ | 9/10 [02:06<00:13, 13.66s/it]
# *====================================================================================================*
# Running prototype model with the following parameters:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'intensity': {'I0': 0.10439999999999999,
#                'Rout': 717.971915,
#                'p': -2.659016,
#                'q': 2.156254},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827},
#  'velocity': {'Mstar': 1.973085,
#               'R_p': 59839148280000.0,
#               'extrap_vfunc': <function Velocity.keplerian at 0x7f7955dafac0>,
#               'phi_p': 0.7853981633974483,
#               'simid': 9,
#               'vel_sign': -1.0,
#               'vsys': 5.099463}}
#
# *====================================================================================================*
# *====================================================================================================*
# Computing disc upper and lower surface coordinates, projected on the sky plane...
# Using height and orientation parameters from prototype model:
#
# {'height_lower': {'Rb': 803.90594,
#                   'p': 1.107099,
#                   'q': 2.859784,
#                   'z0': 14.227028},
#  'height_upper': {'Rb': 108.607483,
#                   'p': 1.65208,
#                   'q': 0.550336,
#                   'z0': 52.680114},
#  'orientation': {'PA': 1.010296,
#                  'incl': 0.7853981633974483,
#                  'xc': -0.91338,
#                  'yc': -1.826827}}
# Saving projected R,phi,z disc coordinates for upper emission surface into .npy binaries...
# Saving projected R,phi,z disc coordinates for lower emission surface into .npy binaries...
# *====================================================================================================*
# 100%|██████████| 10/10 [02:20<00:00, 14.02s/it]

# %%
mmarr = np.array(modelcubes)

# %%
mmarr.shape
# Out:
# (10, 1, 133, 250, 250)

# %%
res = mmarr[[1],0, 48:84]-modelcubes_sim[:, 48:84]

# %%
res.mean(axis=(1,2,3))
# Out:
# array([0.01372405, 0.01407135, 0.01672631, 0.01367052, 0.0138173 ,
#        0.01612652, 0.01348852, 0.01368568, 0.01361025, 0.01654578])

# %%
mmarr.shape
# Out:
# (10, 1, 133, 250, 250)

# %%
modelcubes_sim.shape
# Out:
# (10, 133, 250, 250)

# %%
emu_data_vphi.shape
# Out:
# (233, 1, 256, 256)

# %%
xy = np.linspace(-3,3,256)
xx, yy = np.meshgrid(xy, xy)
rr = np.sqrt(xx**2+yy**2)
mask = (rr>0.4) & (rr<3)
plt.imshow()

# %%
plt.imshow(testset_data[0,1]-(emu_data_vphi[0,0]*1e-2+rr**-0.5)*mask)
plt.colorbar()

# %%
emu_data_vphi.mean()
# Out:
# -0.09008781
