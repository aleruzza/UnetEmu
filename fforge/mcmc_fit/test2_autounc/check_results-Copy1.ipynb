# %%
import h5py

# %%
file = h5py.File('backend_out-Copy2.h5', 'r')

# %%
file.close()

# %%
chain = file['mcmc']['chain']

# %%
import matplotlib.pyplot as plt

# %%
chain.shape
# Out:
# (10000, 32, 3)

# %%
for i in range(32):
    cc = chain[:, i, 2]
    plt.plot(cc[cc!=0], color='black', alpha=0.5)

# %%
chain.shape
# Out:
# (10000, 32, 3)

# %%
from corner import corner
corner(chain[:1750].reshape(-1,3))

# %%
for i in range(32):
    plt.plot(-1*file['mcmc']['log_prob'][:1750, i])
plt.xlim(0,100)
#plt.yscale('log')
# Out:
# (0.0, 100.0)

# %%
file['mcmc']['log_prob'].shape
# Out:
# (15000, 6)
