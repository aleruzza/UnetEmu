# %%
import h5py

# %%
file = h5py.File('backend_out.h5', 'r')

# %%
file.close()

# %%
chain = file['mcmc']['chain']

# %%
import matplotlib.pyplot as plt

# %%
chain.shape
# Out:
# (0, 64, 4)

# %%
for i in range(32):
    cc = chain[:, i, 2]
    plt.plot(cc[cc!=0], color='black', alpha=0.5)

# %%
chain.shape
# Out:
# (10000, 64, 4)

# %%
from corner import corner
corner(chain[:70].reshape(-1,4))

# %%
for i in range(64):
    plt.plot(-1*file['mcmc']['log_prob'][:100, i])
plt.xlim(0,100)
plt.yscale('log')

# %%
file['mcmc']['log_prob'].shape
# Out:
# (15000, 6)
