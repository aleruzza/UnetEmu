# %%
import h5py

# %%
file = h5py.File('backend_test1.h5', 'r')

# %%
file['mcmc']['chain']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 file['mcmc']['chain'][0]
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
# ---> 56 'Could not get source, probably due dynamically evaluated source code.'
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
# ---> 57 'Could not get source, probably due dynamically evaluated source code.'
#
# File /exa/projects/DiscEvol_storage/alessandro.ruzza/dbnets_tuto/dbnetsenv/lib64/python3.12/site-packages/h5py/_hl/dataset.py:820, in Dataset.__getitem__(self, args, new_dtype)
#     818 if self._fast_read_ok and (new_dtype is None):
#     819     try:
# --> 820         return self._fast_reader.read(args)
#     821     except TypeError:
#     822         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:361, in h5py._selector.Reader.read()
# ...
