# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import h5py

# %% [markdown]
# # Open models created during fit

# %%
with h5py.File('mcmc_models.h5', 'r') as f:
    # Check the available datasets
    print("Keys in the HDF5 file:", list(f.keys()))
    
    # Access a dataset (replace 'your_dataset' with the actual name)
    dataset = f['mcmc_models']
    
    # Read the data into a NumPy array
    model_cube = dataset[:]
# Out:
# Keys in the HDF5 file: ['mcmc_models']

# %%
with h5py.File('mcmc_data.h5', 'r') as f:
    # Check the available datasets
    print("Keys in the HDF5 file:", list(f.keys()))
    
    # Access a dataset (replace 'your_dataset' with the actual name)
    dataset = f['mcmc_data']
    
    # Read the data into a NumPy array
    data_real = dataset[:]
mc_data = data_real[0]
# Out:
# Keys in the HDF5 file: ['mcmc_data']

# %%
model_cube.shape
# Out:
# (58, 133, 250, 250)

# %%
plt.imshow(model_cube[-5,62])
plt.colorbar()

# %% [markdown]
# Image above is the model for a point in the chain. It clearly shows that there is a problem

# %% [markdown]
# Below are the data that we are trying to fit

# %%
plt.imshow(data_real[0,62])
plt.colorbar()
# Out:
#   0%|                                                                                                                                                                  | 0/1 [13:25<?, ?it/s]

# %% [markdown]
# # Trying to reconstruct the fitting procedure

# %%
# This does everything before run_mcmc
# %run load_models.py
# Out:
#      _  _                        _
#   __| |(_) ___   ___  _ __ ___  (_) _ __    ___  _ __
#  / _` || |/ __| / __|| '_ ` _ \ | || '_ \  / _ \| '__|
# | (_| || |\__ \| (__ | | | | | || || | | ||  __/| |
#  \__,_||_||___/ \___||_| |_| |_||_||_| |_| \___||_|
#
#
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 120689578165943.16
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 107118059336037.9
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# Setting beam_info var to Beam: BMAJ=0.165413767099392 arcsec BMIN=0.12207780778406399 arcsec BPA=6.09619140625 deg
# Setting beam_kernel var to <astropy.convolution.kernels.Gaussian2DKernel object at 0x7f71007e0be0>
# Available categories for prototyping: dict_keys(['velocity', 'orientation', 'intensity', 'linewidth', 'lineslope', 'height_upper', 'height_lower'])
# Using default and/or tag-based parametric forms for model...
# Setting velocity function to <function keplerian_vertical at 0x7f74b8371c60>
# Setting upper surface height function to <function z_upper_exp_tapered at 0x7f74b8371d80>
# Setting lower surface height function to <function z_lower_exp_tapered at 0x7f74b8371e10>
# Setting intensity function to <function intensity_powerlaw_rout at 0x7f74b83720e0>
# Setting linewidth function to <function linewidth_powerlaw at 0x7f74b83723b0>
# Setting lineslope function to <function lineslope_powerlaw at 0x7f74b8372440>
# Setting line profile function to <function line_profile_bell at 0x7f74b83724d0>
# Setting composite upper+lower line profile function to <function line_uplow_mask at 0x7f74b83725f0>
# Setting velocity function to <bound method Emulator.emulate_v2d of <discminer.emulator.Emulator object at 0x7f75058b5a20>>
# Setting upper surface height function to <function z_upper at 0x7f74b8397010>
# Setting lower surface height function to <function z_lower at 0x7f74b83970a0>
# Setting line profile function to <function Intensity.line_profile_bell at 0x7f74d0fbf130>
# Setting intensity function to <function intensity_powerlaw_rout at 0x7f74b8394d30>

# %% [markdown]
# The following reproduces what is done during a step of the mcmc fit

# %%
data = datacube.data
p0_mean=p0
nwalkers=nwalkers
nsteps=nsteps
tag=tag_out
nthreads=1
# If not specified considers maximum possible number of cores
frac_stats=0.1
frac_stddev=0.1
noise_stddev=noise

# %%
self = model

# %%
#setting data and vchannels properly
if data is None and vchannels is None:
    self.mc_data = self.datacube.data
    self.mc_vchannels = self.vchannels
elif data is not None and vchannels is not None:
    self.mc_data = data
    self.mc_vchannels = vchannels
else:
    raise InputError((data, vchannels),
                     'Please specify both data AND vchannel slices you wish to consider for the MCMC sampling.')
self.mc_nchan = len(vchannels)
self.noise_stddev = noise_stddev

# %%
import emcee as sampler_id

# %%
kwargs_model = {}
kwargs_model.update({'z_mirror': False})

# %%
import copy
self.mc_header, self.mc_kind, self.mc_nparams, self.mc_boundaries_list, self.mc_params_indices = Model._get_params2fit(self.mc_params, self.mc_boundaries)
#self.params = copy.deepcopy(self.mc_params)

# %%
self.params
# Out:
# {'velocity': {'Mstar': 1.973085,
#   'vsys': 5.099463,
#   'vel_sign': -1.0,
#   'extrap_vfunc': <function discminer.disc2d.Velocity.keplerian(coord, Mstar=1.0, vel_sign=1, vsys=0)>,
#   'norm': True},
#  'orientation': {'incl': 0.7853981633974483,
#   'PA': 1.010296,
#   'xc': -0.91338,
#   'yc': -1.826827},
#  'intensity': {'I0': 0.10439999999999999,
#   'p': -2.659016,
#   'q': 2.156254,
#   'Rout': 717.971915},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'height_upper': {'z0': 52.680114,
#   'p': 1.65208,
#   'Rb': 108.607483,
#   'q': 0.550336},
#  'height_lower': {'z0': 14.227028,
#   'p': 1.107099,
#   'Rb': 803.90594,
#   'q': 2.859784}}

# %%
self.mc_params
# Out:
# {'velocity': {'alpha': True,
#   'h': True,
#   'planetMass': True,
#   'sigmaSlope': True,
#   'flaringIndex': True,
#   'R_p': True,
#   'phi_p': True},
#  'orientation': {'incl': 0.7853981633974483,
#   'PA': 1.010296,
#   'xc': -0.91338,
#   'yc': -1.826827},
#  'intensity': {'I0': 0.10439999999999999,
#   'p': -2.659016,
#   'q': 2.156254,
#   'Rout': 717.971915},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'height_upper': {'z0': 52.680114,
#   'p': 1.65208,
#   'Rb': 108.607483,
#   'q': 0.550336},
#  'height_lower': {'z0': 14.227028,
#   'p': 1.107099,
#   'Rb': 803.90594,
#   'q': 2.859784}}

# %%
if isinstance(p0_mean, (list, tuple, np.ndarray)): 
    if len(p0_mean) != self.mc_nparams: raise InputError(p0_mean, 'Length of input p0_mean must be equal to the number of parameters to fit: %d'%self.mc_nparams)
    else: pass

# %%
nstats = int(round(frac_stats*(nsteps-1)))
ndim = self.mc_nparams

p0_stddev = [frac_stddev*(self.mc_boundaries_list[i][1] - self.mc_boundaries_list[i][0]) for i in range(self.mc_nparams)]
#p0 = np.random.normal(loc=p0_mean,
#                      scale=p0_stddev,
 #                     size=(nwalkers, ndim)
 #                     )

# %%
import corner
corner.corner(p0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 import corner
# ----> 2 corner.corner(p0)
#
# File /exa/projects/DiscEvol_storage/alessandro.ruzza/emu+discminer/penv_debug/lib/python3.10/site-packages/corner/corner.py:232, in corner(data, bins, range, axes_scale, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_quantiles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     227 if arviz_corner is None:
#     228     if not (
#     229         isinstance(data, np.ndarray)
#     230         or data.__class__.__name__ == "DataFrame"
#     231     ):
# --> 232         raise ImportError(
#     233             "Please install arviz or use a numpy array as input"
#     234         )
#     236     if (
#     237         var_names is not None
#     238         or filter_vars is not None
#    (...)
#     242         or labeller is not None
#     243     ):
#     244         logging.warning(
#     245             "Please install arviz to use the advanced features of corner"
#     246         )
#
# ImportError: Please install arviz or use a numpy array as input

# %%
new_params = p0

# %%
p0
# Out:
# [0.006, 0.085, 0.0006, 1.1, 0.1, 59839148280000.0, 0.7853981633974483]

# %%
for i in range(self.mc_nparams):
    if not (self.mc_boundaries_list[i][0] < new_params[i] < self.mc_boundaries_list[i][1]): -np.inf
    else: self.params[self.mc_kind[i]][self.mc_header[i]] = new_params[i]

# %%
kwargs_model
# Out:
# {'z_mirror': False}

# %%
vel2d, int2d, linew2d, lineb2d = self.make_model(z_mirror=False)

# %%
model_cube = self.get_cube(self.mc_vchannels, vel2d, int2d, linew2d, lineb2d, return_data_only=True)

# %%
model.params
# Out:
# {'velocity': {'Mstar': 1.973085,
#   'vsys': 5.099463,
#   'vel_sign': -1.0,
#   'extrap_vfunc': <function discminer.disc2d.Velocity.keplerian(coord, Mstar=1.0, vel_sign=1, vsys=0)>,
#   'norm': True,
#   'alpha': 0.006,
#   'h': 0.085,
#   'planetMass': 0.0006,
#   'sigmaSlope': 1.1,
#   'flaringIndex': 0.1,
#   'R_p': 59839148280000.0,
#   'phi_p': 0.7853981633974483},
#  'orientation': {'incl': 0.7853981633974483,
#   'PA': 1.010296,
#   'xc': -0.91338,
#   'yc': -1.826827},
#  'intensity': {'I0': 0.10439999999999999,
#   'p': -2.659016,
#   'q': 2.156254,
#   'Rout': 717.971915},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'lineslope': {'Ls': 1.676401, 'p': 0.314061},
#  'height_upper': {'z0': 52.680114,
#   'p': 1.65208,
#   'Rb': 108.607483,
#   'q': 0.550336},
#  'height_lower': {'z0': 14.227028,
#   'p': 1.107099,
#   'Rb': 803.90594,
#   'q': 2.859784}}

# %%
plt.imshow(datacube.data[62])
plt.colorbar()

# %%
plt.imshow(model_cube[62])
plt.colorbar()

# %%
mass = np.logspace(-5,-2,200)

# %%
np.argmin(np.abs(mass-0.0006))
# Out:
# np.int64(118)

# %%
plt.imshow(emulated_cmaps[0,118,62])

# %%
plt.imshow(vel2d['upper'])

# %%
new_params = p0
self = model
for i in range(self.mc_nparams):
            if not (self.mc_boundaries_list[i][0] < new_params[i] < self.mc_boundaries_list[i][1]): -np.inf
            else: self.params[self.mc_kind[i]][self.mc_header[i]] = new_params[i]

vel2d, int2d, linew2d, lineb2d = self.make_model()

# %%
model.velocity_func
# Out:
# <bound method Emulator.emulate_v2d of <discminer.emulator.Emulator object at 0x7f9213a3a6e0>>

# %%
plt.imshow(vel2d['lower'])

# %%
model.params['velocity']
# Out:
# {'Mstar': 1.973085,
#  'vsys': 5.099463,
#  'vel_sign': -1.0,
#  'extrap_vfunc': <function discminer.disc2d.Velocity.keplerian(coord, Mstar=1.0, vel_sign=1, vsys=0)>,
#  'norm': True,
#  'alpha': 0.006,
#  'h': 0.085,
#  'planetMass': 0.0006,
#  'sigmaSlope': 1.1,
#  'flaringIndex': 0.1,
#  'R_p': 59839148280000.0,
#  'phi_p': 0.7853981633974483}

# %%
res = model.velocity_func(model.grid, **model.params['velocity'])

# %%
res[0]
# Out:
# array([-1.11203166, -1.11383251, -1.1156362 , ..., -1.1156362 ,
#        -1.11383251, -1.11203166], shape=(96100,))

# %%
plt.scatter(model.grid['x'], model.grid['y'], c=res[1])

# %%
model.mc_vchannels = model.vchannels
model_cube = self.get_cube(self.mc_vchannels, vel2d, int2d, linew2d, lineb2d, return_data_only=True)

# %%
plt.imshow(model_cube[62])

# %%
model.params['velocity']
# Out:
# {'Mstar': 1.973085,
#  'vsys': 5.099463,
#  'vel_sign': -1.0,
#  'extrap_vfunc': <function discminer.disc2d.Velocity.keplerian(coord, Mstar=1.0, vel_sign=1, vsys=0)>,
#  'norm': True,
#  'alpha': 0.006,
#  'h': 0.085,
#  'planetMass': 0.0006,
#  'sigmaSlope': 1.1,
#  'flaringIndex': 0.1,
#  'R_p': 59839148280000.0,
#  'phi_p': 0.7853981633974483}

# %%
from discminer.mining_utils import init_data_and_model
dat, model_init = init_data_and_model()
# Out:
#      _  _                        _
#   __| |(_) ___   ___  _ __ ___  (_) _ __    ___  _ __
#  / _` || |/ __| / __|| '_ ` _ \ | || '_ \  / _ \| '__|
# | (_| || |\__ \| (__ | | | | | || || | | ||  __/| |
#  \__,_||_||___/ \___||_| |_| |_||_||_| |_| \___||_|
#
#
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 120689578165943.16
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# *====================================================================================================*
# Computing grid...
# Grid maximum extent: 117781395559534.89
# Grid step (cell size): 969394202136.0896
# *====================================================================================================*
# Setting beam_info var to Beam: BMAJ=0.165413767099392 arcsec BMIN=0.12207780778406399 arcsec BPA=6.09619140625 deg
# Setting beam_kernel var to <astropy.convolution.kernels.Gaussian2DKernel object at 0x7f3709afd870>
# Available categories for prototyping: dict_keys(['velocity', 'orientation', 'intensity', 'linewidth', 'lineslope', 'height_upper', 'height_lower'])
# Using default and/or tag-based parametric forms for model...
# Setting velocity function to <function keplerian_vertical at 0x7f3721928ca0>
# Setting upper surface height function to <function z_upper_exp_tapered at 0x7f3721928dc0>
# Setting lower surface height function to <function z_lower_exp_tapered at 0x7f3721928e50>
# Setting intensity function to <function intensity_powerlaw_rout at 0x7f3721929120>
# Setting linewidth function to <function linewidth_powerlaw at 0x7f37219293f0>
# Setting lineslope function to <function lineslope_powerlaw at 0x7f3721929480>
# Setting line profile function to <function line_profile_bell at 0x7f3721929510>
# Setting composite upper+lower line profile function to <function line_uplow_mask at 0x7f3721929630>

# %%
model_init.mc_params
# Out:
# {'velocity': {'Mstar': True, 'vel_sign': 1, 'vsys': 0},
#  'orientation': {'incl': True, 'PA': True, 'xc': False, 'yc': False},
#  'intensity': {'I0': True, 'p': True, 'q': False},
#  'linewidth': {'L0': True, 'p': True, 'q': 0.1},
#  'lineslope': {'Ls': False, 'p': False, 'q': False},
#  'height_upper': {'psi': True},
#  'height_lower': {'psi': True}}

# %%
model.mc_params
# Out:
# {'velocity': {'Mstar': 1.973085,
#   'vel_sign': -1,
#   'vsys': 0,
#   'extrap_vfunc': <function discminer.disc2d.Velocity.keplerian(coord, Mstar=1.0, vel_sign=1, vsys=0)>,
#   'alpha': True,
#   'h': True,
#   'planetMass': True,
#   'sigmaSlope': True,
#   'flaringIndex': True,
#   'R_p': True,
#   'phi_p': True},
#  'orientation': {'incl': 0.7853981633974483,
#   'PA': 1.010296,
#   'xc': False,
#   'yc': False},
#  'intensity': {'I0': 0.10439999999999999, 'p': -2.659016, 'q': 2.156254},
#  'linewidth': {'L0': 0.316459, 'p': -0.288951, 'q': -0.355926},
#  'lineslope': {'Ls': False, 'p': False, 'q': False},
#  'height_upper': {'z0': 52.680114,
#   'p': 1.65208,
#   'Rb': 108.607483,
#   'q': 0.550336},
#  'height_lower': {'z0': 14.227028,
#   'p': 1.107099,
#   'Rb': 803.90594,
#   'q': 2.859784}}

# %% [markdown]
# # check minimu

# %%
from astropy.io import fits
data = fits.open('fake_data_id4_rms1e-5.fits')[0].data

# %%
from tqdm import tqdm

# %%
def ln_likelihood(model_cube, mc_data, noise=1):
    lnx2 = 0
    for i in range(model_cube.shape[0]):
        model_chan = model_cube[i]
        mask_data = np.isfinite(mc_data[i])
        mask_model = np.isfinite(model_chan)
        data = np.where(np.logical_and(mask_model, ~mask_data), 0, mc_data[i])
        model = np.where(np.logical_and(mask_data, ~mask_model), 0, model_chan)
        mask = np.logical_and(mask_data, mask_model)
        lnx =  np.where(mask, np.power((data - model)/noise, 2), 0) 
        lnx2 += -0.5 * np.sum(lnx)
    
    return lnx2 if np.isfinite(lnx2) else -np.inf

# %%
emulated_cmaps = np.load('../generate_cmaps/modelcubes_emu_conv_varyingonlyplanetmass_id4_jb.npy')

# %%
lk = [ln_likelihood(m, data) for m in tqdm(emulated_cmaps[0])]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:08<00:00, 24.18it/s]

# %%
self.noise_stddev
# Out:
# 1e-05

# %%
nlk = -1*np.array(lk)
plt.plot(np.logspace(-5,-2,200), nlk)
plt.yscale('log')
plt.xscale('log')

# %%
data.shape
# Out:
# (133, 250, 250)

# %%
plt.imshow(data[62])

# %%
plt.imshow(emulated_cmaps[0][199][62])
