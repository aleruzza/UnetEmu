# %%
import numpy as np
import matplotlib.pyplot as plt
from fforge.inference.emulator import Emulator
from fforge.utils.utils import vr_norm, vaz_norm, generate_ict_128x128_disc_tri_slopes, nullv
import fforge.utils.units as u

# %% [markdown]
# # Load the emulator

# %%
#setup emulator
labels = ["vphi", "vr"]
pths = [
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vphi_256/model__epoch_1980_test_vaz_256.pth",
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vr_256/model__epoch_1980_test_vr_256.pth",
]
params = [
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vphi_256/params.py",
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vr_256/params.py",
]

#functions used to denormalize the emulator output
norm_funcs = [vaz_norm, vr_norm]

emu = Emulator(
    model_pths=pths,
    labels=["vphi", "vr"],
    model_params=params,
    norm_funcs=norm_funcs,
    ict_gen=generate_ict_128x128_disc_tri_slopes,
)

# %% [markdown]
# # Test the emulator usage

# %%
emu.emulate_v3d?
# Out:
# Signature:
# emu.emulate_v3d(
#     coord,
#     alpha,
#     h,
#     planetMass,
#     flaringIndex,
#     R_p,
#     phi_p,
#     extrap_vfunc,
#     sigmaSlope=None,
#     norm=True,
#     interp_3d='SPHERICAL',
#     **extrap_kwargs,
# )
# Docstring: <no docstring>
# File:      ~/UNI/SCIENCE/UnetEmu/fforge/src/fforge/inference/emulator.py
# Type:      method

# %%
# %%time
#define the coordinates
xy = np.linspace(-3,3,256)*u.au
xx, yy = np.meshgrid(xy,xy)
coord = {'x': xx, 'y': yy, 'z': xx*0}

#define the parameters
params = {
    'alpha': 1e-2,
    'h': 0.1,
    'planetMass': 3e-3,
    'flaringIndex': 0.5}

#emulate
emulated_V = emu.emulate_v3d(coord, **params, R_p=1*u.au, phi_p=np.pi/3, extrap_vfunc=nullv)
# Out:
# computing phi
# CPU times: user 23.1 s, sys: 1.12 s, total: 24.2 s
# Wall time: 6.37 s

# %%
# %%timeit
res = emu.emulate(alpha=1e-3, h=0.1, planetMass=1e-3, sigmaSlope=1, flaringIndex=0.25, fields=['vphi', 'vr'], norm=True)
# Out:
# 3.14 s ± 94 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
G = 6.67384e-11

# %%
u.MSun
# Out:
# 1.9891e+30

# %%
np.sqrt(G * u.MSun / u.au)*1e3*np.sqrt(xy**2+xy**2)**-0.5
# Out:
# array([ 37.39148088,  37.53898237,  37.68824332,  37.83929901,
#         37.99218569,  38.14694065,  38.30360226,  38.46220999,
#         38.62280446,  38.78542752,  38.95012222,  39.11693293,
#         39.28590535,  39.45708657,  39.63052515,  39.80627114,
#         39.98437615,  40.16489344,  40.34787795,  40.53338641,
#         40.72147738,  40.91221134,  41.10565077,  41.30186025,
#         41.50090651,  41.70285858,  41.90778787,  42.11576824,
#         42.32687617,  42.54119084,  42.75879426,  42.97977141,
#         43.20421039,  43.43220253,  43.66384258,  43.89922889,
#         44.13846351,  44.38165248,  44.62890594,  44.88033838,
#         45.13606888,  45.39622128,  45.66092453,  45.93031285,
#         46.20452611,  46.48371008,  46.76801676,  47.05760477,
#         47.35263967,  47.65329437,  47.95974958,  48.27219425,
#         48.59082606,  48.91585193,  49.24748862,  49.58596331,
#         49.93151428,  50.28439156,  50.64485776,  51.01318885,
#         51.38967506,  51.77462183,  52.16835086,  52.57120125,
#         52.98353071,  53.40571691,  53.83815893,  54.28127882,
#         54.73552338,  55.20136602,  55.67930885,  56.16988492,
#         56.67366079,  57.19123922,  57.7232622 ,  58.27041436,
#         58.83342661,  59.41308028,  60.01021166,  60.62571712,
#         61.26055869,  61.91577047,  62.59246566,  63.29184452,
#         64.01520337,  64.76394466,  65.53958841,  66.34378523,
#         67.17833105,  68.04518408,  68.94648407,  69.88457459,
#         70.8620287 ,  71.88167863,  72.9466504 ,  74.06040413,
#         75.22678146,  76.45006137,  77.73502634,  79.0870412 ,
#         80.51214757,  82.01717778,  83.60989304,  85.29915243,
#         87.09512101,  89.00952819,  91.05599158,  93.25042665,
#         95.6115706 ,  98.16165995, 100.92731825, 103.94073557,
#        107.24126025, 110.8775847 , 114.91080678, 119.41881341,
#        124.50271952, 130.29660758, 136.98277358, 144.81658275,
#        154.16902518, 165.60409807, 180.03063499, 199.03135568,
#        225.68034438, 267.02858457, 344.73242033, 597.09406704,
#        597.09406704, 344.73242033, 267.02858457, 225.68034438,
#        199.03135568, 180.03063499, 165.60409807, 154.16902518,
#        144.81658275, 136.98277358, 130.29660758, 124.50271952,
#        119.41881341, 114.91080678, 110.8775847 , 107.24126025,
#        103.94073557, 100.92731825,  98.16165995,  95.6115706 ,
#         93.25042665,  91.05599158,  89.00952819,  87.09512101,
#         85.29915243,  83.60989304,  82.01717778,  80.51214757,
#         79.0870412 ,  77.73502634,  76.45006137,  75.22678146,
#         74.06040413,  72.9466504 ,  71.88167863,  70.8620287 ,
#         69.88457459,  68.94648407,  68.04518408,  67.17833105,
#         66.34378523,  65.53958841,  64.76394466,  64.01520337,
#         63.29184452,  62.59246566,  61.91577047,  61.26055869,
#         60.62571712,  60.01021166,  59.41308028,  58.83342661,
#         58.27041436,  57.7232622 ,  57.19123922,  56.67366079,
#         56.16988492,  55.67930885,  55.20136602,  54.73552338,
#         54.28127882,  53.83815893,  53.40571691,  52.98353071,
#         52.57120125,  52.16835086,  51.77462183,  51.38967506,
#         51.01318885,  50.64485776,  50.28439156,  49.93151428,
#         49.58596331,  49.24748862,  48.91585193,  48.59082606,
#         48.27219425,  47.95974958,  47.65329437,  47.35263967,
#         47.05760477,  46.76801676,  46.48371008,  46.20452611,
#         45.93031285,  45.66092453,  45.39622128,  45.13606888,
#         44.88033838,  44.62890594,  44.38165248,  44.13846351,
#         43.89922889,  43.66384258,  43.43220253,  43.20421039,
#         42.97977141,  42.75879426,  42.54119084,  42.32687617,
#         42.11576824,  41.90778787,  41.70285858,  41.50090651,
#         41.30186025,  41.10565077,  40.91221134,  40.72147738,
#         40.53338641,  40.34787795,  40.16489344,  39.98437615,
#         39.80627114,  39.63052515,  39.45708657,  39.28590535,
#         39.11693293,  38.95012222,  38.78542752,  38.62280446,
#         38.46220999,  38.30360226,  38.14694065,  37.99218569,
#         37.83929901,  37.68824332,  37.53898237,  37.39148088])

# %%
xx, yy = np.meshgrid(xy,xy)
plt.pcolormesh(xy/u.au, xy/u.au, np.sqrt(G * u.MSun)*1e-3*np.sqrt(xx**2+yy**2)**-0.5, vmax=1)
plt.colorbar()

# %%
plt.pcolormesh(xy/u.au, xy/u.au, emulated_V[0])
phi = np.linspace(-np.pi, np.pi, 100)
plt.scatter(np.cos(phi), np.sin(phi), marker='.')
plt.gca().set_aspect('equal')
plt.colorbar()

# %%
plt.pcolormesh(xy/u.au, xy/u.au, np.arctan2(coord['y'], coord['x']))
plt.gca().set_aspect('equal')
