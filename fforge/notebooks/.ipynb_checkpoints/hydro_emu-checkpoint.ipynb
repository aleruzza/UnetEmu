# %%
import numpy as np
import matplotlib.pyplot as plt
from fforge.inference.emulator import Emulator
from fforge.utils.utils import vr_norm, vaz_norm, generate_ict_128x128_disc_tri_slopes, nullv
import fforge.utils.units as u
from discminer.model import keplerian

# %% [markdown]
# # Load the emulator

# %%
#setup emulator
labels = ["vphi", "vr"]
pths = [
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vphi_256/model__epoch_1980_test_vaz_256.pth",
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vr_256/model__epoch_1980_test_vr_256.pth",
]
params = [
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vphi_256/params.py",
    "/home/aleruzza/UNI/SCIENCE/UnetEmu/trained_models/vr_256/params.py",
]

#functions used to denormalize the emulator output
norm_funcs = [vaz_norm, vr_norm]

emu = Emulator(
    model_pths=pths,
    labels=["vphi", "vr"],
    model_params=params,
    norm_funcs=norm_funcs,
    ict_gen=generate_ict_128x128_disc_tri_slopes,
)

# %% [markdown]
# # Test the emulator usage

# %%
emu.emulate_v3d?
# Out:
# Signature:
# emu.emulate_v3d(
#     coord,
#     alpha,
#     h,
#     planetMass,
#     flaringIndex,
#     R_p,
#     phi_p,
#     extrap_vfunc,
#     sigmaSlope=None,
#     norm=True,
#     interp_3d='SPHERICAL',
#     discminer_integr=True,
#     mask_only_ppos=False,
#     **extrap_kwargs,
# )
# Docstring: <no docstring>
# File:      ~/UNI/SCIENCE/UnetEmu/fforge/src/fforge/inference/emulator.py
# Type:      method

# %%
# %%time
#define the coordinates
xy = np.linspace(-3,3,256)*u.au
xx, yy = np.meshgrid(xy,xy)
coord = {'x': xx, 'y': yy, 'z': xx*0}

#define the parameters
params = {
    'alpha': 1e-2,
    'h': 0.1,
    'planetMass': 3e-3,
    'flaringIndex': 0.5}

#emulate
emulated_V_sing = emu.emulate_v3d(coord, **params, R_p=1*u.au, phi_p=np.pi/3, extrap_vfunc=keplerian, vel_sign=-1)
# Out:
# CPU times: user 17.4 s, sys: 3.16 s, total: 20.5 s
# Wall time: 5.41 s

# %%
emulated_V_sing.shape
# Out:
# (3, 256, 256)

# %%
plt.pcolormesh(xy/u.au, xy/u.au, emulated_V_sing[1])
plt.colorbar()
phi = np.linspace(-np.pi, np.pi, 100)
plt.scatter(np.cos(phi), np.sin(phi), marker='.')
plt.scatter(xy/u.au*np.cos(np.pi/3), xy/u.au*np.sin(np.pi/3), marker='.')
plt.gca().set_aspect('equal')

# %% [markdown]
# # Masking all but planet position

# %%
emulated_V_sing_pposmask = emu.emulate_v3d(coord, **params, R_p=1*u.au, phi_p=np.pi/3, extrap_vfunc=keplerian, vel_sign=-1, mask_only_ppos=True)

# %%
plt.pcolormesh(xy/u.au, xy/u.au, emulated_V_sing_pposmask[1])
plt.colorbar()
phi = np.linspace(-np.pi, np.pi, 100)
#plt.scatter(np.cos(phi), np.sin(phi), marker='.')
#plt.scatter(xy/u.au*np.cos(np.pi/3), xy/u.au*np.sin(np.pi/3), marker='.')
plt.gca().set_aspect('equal')

# %% [markdown]
# # Emulating batches
#
# I want to have arrays of properties and get an array of velocity matrices.

# %%
# %%time
xy = np.linspace(-3,3,256)*u.au
xx, yy = np.meshgrid(xy,xy)
coord = {'x': xx, 'y': yy, 'z': xx*0}

#define the parameters
params = {
    'alpha': [1e-2, 1e-2,1e-3],
    'h': [0.1, 0.1, 0.05],
    'planetMass': [3e-3, 0.1e-3, 2e-3],
    'flaringIndex': [0.5, 0.2, 0.1]}

#emulate
emulated_V = emu.emulate_v3d(coord, **params, R_p=1*u.au, phi_p=np.pi/3, extrap_vfunc=nullv, discminer_integr=False)
# Out:
# CPU times: user 49.2 s, sys: 1min, total: 1min 49s
# Wall time: 25.5 s

# %%
emulated_V.shape
# Out:
# (3, 3, 256, 256)

# %%
plt.imshow(emulated_V[0,1])
plt.colorbar()

# %%
plt.imshow((emulated_V_sing[0]-emulated_V[0])[1])
plt.colorbar()

# %%
(((emulated_V_sing[0]-emulated_V[0]))**2).mean()
# Out:
# np.float64(2.1190621396859154e-13)

# %%
emulated_V_sing2 = emu.emulate_v3d(coord, **params, R_p=1*u.au, phi_p=np.pi/3, extrap_vfunc=nullv)

# %%
plt.imshow((emulated_V[0]-emulated_V_sing2[0])[1])
plt.colorbar()
